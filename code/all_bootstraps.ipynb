# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### angiosperms

# %%
### angiosperms

paths_aa_complete = ["clustal.notrim_yabby.aa.fasta.treefile.support","macse.yabby_sequences.aa.fasta.treefile.support","mafft.notrim_yabby.aa.fasta.treefile.support","muscle.notrim_yabby.aa.fasta.treefile.support",
"trimal_clean.clustal.notrim_yabby.aa.fasta.treefile.support","trimal_clean.macse.yabby_sequences.aa.fasta.treefile.support","trimal_clean.mafft.notrim_yabby.aa.fasta.treefile.support","trimal_clean.muscle.notrim_yabby.aa.fasta.treefile.support",
"clustal.notrim_yabby.aa_hmm.fasta.treefile.support","macse.yabby_sequences.aa_hmm.fasta.treefile.support","mafft.notrim_yabby.aa_hmm.fasta.treefile.support","muscle.notrim_yabby.aa_hmm.fasta.treefile.support"]

paths_codon_complete = ["codon.clustal.notrim_yabby.aa.fasta.treefile.support","macse.yabby_sequences.fasta.treefile.support","codon.mafft.notrim_yabby.aa.fasta.treefile.support","codon.muscle.notrim_yabby.aa.fasta.treefile.support",
 "trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support","trimal_clean.macse.yabby_sequences.fasta.treefile.support", "trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support","trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
 "transfo_macse.yabby_sequences.fasta.treefile.support", "transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support", "transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support","transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support"]

paths_nt_complete = ["codon.clustal.notrim_yabby.aa.fasta.treefile.support","macse.yabby_sequences.fasta.treefile.support","codon.mafft.notrim_yabby.aa.fasta.treefile.support","codon.muscle.notrim_yabby.aa.fasta.treefile.support",
                     "trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support","trimal_clean.macse.yabby_sequences.fasta.treefile.support","trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support","trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
                     "transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support","transfo_macse.yabby_sequences.fasta.treefile.support","transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support","transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]

paths_aa_domain =["clustal.notrim_yabby.aa.fasta.treefile.support","macse.yabby_sequences.aa.fasta.treefile.support","mafft.notrim_yabby.aa.fasta.treefile.support","muscle.notrim_yabby.aa.fasta.treefile.support",
"trimal_clean.clustal.notrim_yabby.aa.fasta.treefile.support","trimal_clean.macse.yabby_sequences.aa.fasta.treefile.support","trimal_clean.mafft.notrim_yabby.aa.fasta.treefile.support","trimal_clean.muscle.notrim_yabby.aa.fasta.treefile.support",
"clustal.notrim_yabby.aa_hmm.fasta.treefile.support","macse.yabby_sequences.aa_hmm.fasta.treefile.support","mafft.notrim_yabby.aa_hmm.fasta.treefile.support","muscle.notrim_yabby.aa_hmm.fasta.treefile.support"]

paths_codon_domain = ["codon.clustal.notrim_yabby.aa.fasta.treefile.support","macse.yabby_sequences.fasta.treefile.support","codon.mafft.notrim_yabby.aa.fasta.treefile.support","codon.muscle.notrim_yabby.aa.fasta.treefile.support",
                      "trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support","trimal_clean.macse.yabby_sequences.fasta.treefile.support","trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support","trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
                      "transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support","transfo_macse.yabby_sequences.fasta.treefile.support","transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support","transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support"]

paths_nt_domain = ["codon.clustal.notrim_yabby.aa.fasta.treefile.support","macse.yabby_sequences.fasta.treefile.support","codon.mafft.notrim_yabby.aa.fasta.treefile.support","codon.muscle.notrim_yabby.aa.fasta.treefile.support",
                   "trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support","trimal_clean.macse.yabby_sequences.fasta.treefile.support","trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support","trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
                   "transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support","transfo_macse.yabby_sequences.fasta.treefile.support","transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support","transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]

path = "/mnt/pbil/Infer_Anth/align/angio/"
folder = ["results_align_angio/", "results_align_angio_codon/", "results_align_angio_nt-3/", "results_align_angio_domain/", "results_align_angio_domain_codon/", "results_align_angio_domain_nt-3/"]

analyses = ["analyses_angio_aa_complete", "analyses_angio_codon_complete", "analyses_angio_nt_complete", "analyses_angio_aa_domain", "analyses_angio_codon_domain", "analyses_angio_nt_domain"]
analyses_name = ["aa_complete", "codon_complete", "nt_complete", "aa_domain", "codon_domain", "nt_domain"]

paths = [paths_aa_complete, paths_codon_complete, paths_nt_complete, paths_aa_domain, paths_codon_domain, paths_nt_domain]
methods_trim = ["clustal_none","macse_none", "mafft_none", "muscle_none", "clustal_80", "macse_80", "mafft_80", "muscle_80", "clustal_hmm", "macse_hmm", "mafft_hmm", "muscle_hmm"]

bootstrap_complete_aa = {i:[] for i in methods_trim}
bootstrap_complete_codon = {i:[] for i in methods_trim}
bootstrap_complete_nt = {i:[] for i in methods_trim}
bootstrap_domain_aa = {i:[] for i in methods_trim}
bootstrap_domain_codon = {i:[] for i in methods_trim}
bootstrap_domain_nt = {i:[] for i in methods_trim}

dicts_angio = [bootstrap_complete_aa,bootstrap_complete_codon, bootstrap_complete_nt, bootstrap_domain_aa,bootstrap_domain_codon, bootstrap_domain_nt]


for i, analysis in enumerate(analyses):
    for j, method in enumerate(methods_trim):
        for line in open(path+folder[i]+paths[i][j]): 
            a = line.strip()
            if a.isnumeric():
                dicts_angio[i][method].append(int(a))

# %%
#analyses_DF = ["analyses_angio_aa_complete_df", "analyses_angio_codon_complete_df", "analyses_angio_nt_complete_df", "analyses_angio_aa_domain_df", "analyses_angio_codon_domain_df",  "analyses_angio_nt_domain_df"]

analyses_angio_aa_complete_df = pd.DataFrame(dicts_angio[0])

analyses_name = ["aa_complete", "codon_complete", "nt_complete", "aa_domain", "codon_domain", "nt_domain"]
methods = ["clustal","macse", "mafft", "muscle"]
trimming = ["none","less gap", "hmmcleaner"]


methods_trim = ["clustal_none","macse_none", "mafft_none", "muscle_none", "clustal_80", "macse_80", "mafft_80", "muscle_80", "clustal_hmm", "macse_hmm", "mafft_hmm", "muscle_hmm"]

data_type = []
for i in analyses_name:
    for j in [(j,i) for i in trimming for j in methods]:
        data_type.append(i)

aligner_type = methods * len(analyses_name)*len(trimming)

trimming_type = []
for a in range(len(analyses_name)):
    for i in trimming:
        for j in methods:
            trimming_type.append(i)

bootstraps = []
for i in range(len(analyses_name)):
    for j in methods_trim:
        bootstraps.append(dicts_angio[i][j])

df_angio = pd.DataFrame([data_type,aligner_type, trimming_type]).T
df_angio.columns = ['data type', 'aligner', 'trimming']

boots_angio_df = pd.DataFrame([i for i in bootstraps])

DF_angio = pd.concat([df_angio, boots_angio_df], axis=1)

# %%
df_angio_melted = pd.melt(DF_angio, id_vars=["data type", "trimming"], 
                    value_vars=list(range(DF_angio.columns[-1]+1)),
                    var_name="category", value_name="value")

# %% [markdown]
# ### gymnosperms

# %%
### gymnosperms

paths_aa_complete = ["results_gymno_cycas_aa/clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa/macse.yabby_sequences.aa.fasta.treefile.support",
"results_gymno_cycas_aa/mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa/muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa/trimal_clean.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa/trimal_clean.macse.yabby_sequences.aa.fasta.treefile.support",
"results_gymno_cycas_aa/trimal_clean.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa/trimal_clean.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa/clustal.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_gymno_cycas_aa/macse.yabby_sequences.aa_hmm.fasta.treefile.support",
"results_gymno_cycas_aa/mafft.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_gymno_cycas_aa/muscle.notrim_yabby.aa_hmm.fasta.treefile.support",]

paths_aa_domain =["results_gymno_cycas_aa_domain/clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/macse.yabby_sequences.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/trimal_clean.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/trimal_clean.macse.yabby_sequences.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/trimal_clean.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/trimal_clean.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_aa_domain/clustal.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_gymno_cycas_aa_domain/macse.yabby_sequences.aa_hmm.fasta.treefile.support",
"results_gymno_cycas_aa_domain/mafft.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_gymno_cycas_aa_domain/muscle.notrim_yabby.aa_hmm.fasta.treefile.support",]

paths_codon_domain =["results_gymno_cycas_codon_domain/codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_codon_domain/codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/trimal_clean.macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_codon_domain/trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/transfo_macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_codon_domain/transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_codon_domain/transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]

paths_nt_complete=["results_gymno_cycas_nt/codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/codon.macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_nt/codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/trimal_clean.codon.macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_nt/trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/transfo_codon.macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_nt/transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt/transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]

paths_nt_domain=["results_gymno_cycas_nt_domain/codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/codon.macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_nt_domain/codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/trimal_clean.codon.macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_nt_domain/trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/transfo_codon.macse.yabby_sequences.fasta.treefile.support",
"results_gymno_cycas_nt_domain/transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_gymno_cycas_nt_domain/transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]

path = "/mnt/pbil/Infer_Anth/align/gymno/"

analyses = ["analyses_gymno_aa_complete", "analyses_gymno_nt_complete", "analyses_gymno_aa_domain", "analyses_gymno_codon_domain", "analyses_gymno_nt_domain"]
analyses_name = ["aa_complete", "nt_complete", "aa_domain", "codon_domain", "nt_domain"]

paths = [paths_aa_complete, paths_nt_complete, paths_aa_domain, paths_codon_domain, paths_nt_domain]
methods_trim = ["clustal_none","macse_none", "mafft_none", "muscle_none", "clustal_80", "macse_80", "mafft_80", "muscle_80", "clustal_hmm", "macse_hmm", "mafft_hmm", "muscle_hmm"]

bootstrap_complete_aa = {i:[] for i in methods_trim}
bootstrap_complete_nt = {i:[] for i in methods_trim}
bootstrap_domain_aa = {i:[] for i in methods_trim}
bootstrap_domain_codon = {i:[] for i in methods_trim}
bootstrap_domain_nt = {i:[] for i in methods_trim}

dicts_gymno = [bootstrap_complete_aa, bootstrap_complete_nt, bootstrap_domain_aa,bootstrap_domain_codon, bootstrap_domain_nt]


for i, analysis in enumerate(analyses):
    for j, method in enumerate(methods_trim):
        for line in open(path+paths[i][j]): 
            a = line.strip()
            if a.isnumeric():
                dicts_gymno[i][method].append(int(a))

# %%
#analyses_DF = ["analyses_angio_aa_complete_df", "analyses_angio_codon_complete_df", "analyses_angio_nt_complete_df", "analyses_angio_aa_domain_df", "analyses_angio_codon_domain_df",  "analyses_angio_nt_domain_df"]

analyses_name = ["aa_complete", "nt_complete", "aa_domain", "codon_domain", "nt_domain"]
methods = ["clustal","macse", "mafft", "muscle"]
trimming = ["none","less gap", "hmmcleaner"]

methods_trim = ["clustal_none","macse_none", "mafft_none", "muscle_none", "clustal_80", "macse_80", "mafft_80", "muscle_80", "clustal_hmm", "macse_hmm", "mafft_hmm", "muscle_hmm"]

data_type = []
for i in analyses_name:
    for j in [(j,i) for i in trimming for j in methods]:
        data_type.append(i)

aligner_type = methods * len(analyses_name)*len(trimming)

trimming_type = []
for a in range(5):
    for i in trimming:
        for j in methods:
            trimming_type.append(i)

bootstraps = []
for i in range(len(analyses_name)):
    for j in methods_trim:
        bootstraps.append(dicts_gymno[i][j])

df_gymno = pd.DataFrame([data_type,aligner_type, trimming_type]).T
df_gymno.columns = ['data type', 'aligner', 'trimming']

boots_df_gymno = pd.DataFrame([i for i in bootstraps])

DF_gymno = pd.concat([df_gymno, boots_df_gymno], axis=1)

# %%
df_gymno_melted = pd.melt(DF_gymno, id_vars=["data type", "trimming"], 
                    value_vars=list(range(DF_gymno.columns[-1]+1)),
                    var_name="category", value_name="value")

# %% [markdown]
# ### seedplants

# %%
paths_aa_complete = ["results_seedplants_cycas_aa/clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/macse.yabby_sequences.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/trimal_clean.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/trimal_clean.macse.yabby_sequences.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/trimal_clean.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/trimal_clean.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa/clustal.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_seedplants_cycas_aa/macse.yabby_sequences.aa_hmm.fasta.treefile.support",
"results_seedplants_cycas_aa/mafft.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_seedplants_cycas_aa/muscle.notrim_yabby.aa_hmm.fasta.treefile.support",]

paths_nt_complete = ["results_seedplants_cycas_nt/codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/codon.macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_nt/codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/trimal_clean.codon.macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_nt/trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/transfo_codon.macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_nt/transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt/transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]

paths_aa_domain = ["results_seedplants_cycas_aa_domain/clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/macse.yabby_sequences.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/trimal_clean.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/trimal_clean.macse.yabby_sequences.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/trimal_clean.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/trimal_clean.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/clustal.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/macse.yabby_sequences.aa_hmm.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/mafft.notrim_yabby.aa_hmm.fasta.treefile.support",
"results_seedplants_cycas_aa_domain/muscle.notrim_yabby.aa_hmm.fasta.treefile.support",]

paths_codon_domain =["results_seedplants_cycas_codon_domain/codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/trimal_clean.macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/transfo_macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_codon_domain/transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]

paths_nt_domain =["results_seedplants_cycas_nt_domain/codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/codon.macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/trimal_clean.codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/trimal_clean.codon.macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/trimal_clean.codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/trimal_clean.codon.muscle.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/transfo_codon.clustal.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/transfo_codon.macse.yabby_sequences.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/transfo_codon.mafft.notrim_yabby.aa.fasta.treefile.support",
"results_seedplants_cycas_nt_domain/transfo_codon.muscle.notrim_yabby.aa.fasta.treefile.support",]


path = "/mnt/pbil/Infer_Anth/align/seedplants/cycas/"

analyses = ["analyses_seedplants_aa_complete", "analyses_seedplants_nt_complete", "analyses_seedplants_aa_domain", "analyses_seedplants_codon_domain", "analyses_seedplants_nt_domain"]
analyses_name = ["aa_complete", "nt_complete", "aa_domain", "codon_domain", "nt_domain"]

paths = [paths_aa_complete, paths_nt_complete, paths_aa_domain, paths_codon_domain, paths_nt_domain]
methods_trim = ["clustal_none","macse_none", "mafft_none", "muscle_none", "clustal_80", "macse_80", "mafft_80", "muscle_80", "clustal_hmm", "macse_hmm", "mafft_hmm", "muscle_hmm"]

bootstrap_complete_aa = {i:[] for i in methods_trim}
bootstrap_complete_nt = {i:[] for i in methods_trim}
bootstrap_domain_aa = {i:[] for i in methods_trim}
bootstrap_domain_codon = {i:[] for i in methods_trim}
bootstrap_domain_nt = {i:[] for i in methods_trim}

dicts_seedplants = [bootstrap_complete_aa, bootstrap_complete_nt, bootstrap_domain_aa,bootstrap_domain_codon, bootstrap_domain_nt]


for i, analysis in enumerate(analyses):
    for j, method in enumerate(methods_trim):
        for line in open(path+paths[i][j]): 
            a = line.strip()
            if a.isnumeric():
                dicts_seedplants[i][method].append(int(a))

# %%
#analyses_DF = ["analyses_angio_aa_complete_df", "analyses_angio_codon_complete_df", "analyses_angio_nt_complete_df", "analyses_angio_aa_domain_df", "analyses_angio_codon_domain_df",  "analyses_angio_nt_domain_df"]

analyses_name = ["aa_complete", "nt_complete", "aa_domain", "codon_domain", "nt_domain"]
methods = ["clustal","macse", "mafft", "muscle"]
trimming = ["none","less gap", "hmmcleaner"]

methods_trim = ["clustal_none","macse_none", "mafft_none", "muscle_none", "clustal_80", "macse_80", "mafft_80", "muscle_80", "clustal_hmm", "macse_hmm", "mafft_hmm", "muscle_hmm"]

data_type = []
for i in analyses_name:
    for j in [(j,i) for i in trimming for j in methods]:
        data_type.append(i)

aligner_type = methods * 15

trimming_type = []
for a in range(5):
    for i in trimming:
        for j in methods:
            trimming_type.append(i)


bootstraps = []
for i in range(len(analyses_name)):
    for j in methods_trim:
        bootstraps.append(dicts_seedplants[i][j])

df_seedplants = pd.DataFrame([data_type,aligner_type, trimming_type]).T
df_seedplants.columns = ['data type', 'aligner', 'trimming']

boots_df_seedplants = pd.DataFrame([i for i in bootstraps])

DF_seedplants = pd.concat([df_seedplants, boots_df_seedplants], axis=1)

# %%
df_seedplants_melted = pd.melt(DF_seedplants, id_vars=["data type", "trimming"], 
                    value_vars=list(range(DF_seedplants.columns[-1]+1)),
                    var_name="category", value_name="value")

# %%
order_seedplants = ["codon_domain", "aa_complete", "aa_domain",  "nt_complete", "nt_domain"]
order_gymno = ["codon_domain", "aa_complete", "aa_domain",  "nt_complete", "nt_domain"]
order_angio = ["codon_complete", "codon_domain", "aa_complete", "aa_domain",  "nt_complete", "nt_domain"]

fig, axes = plt.subplots(1, 3, figsize=(30, 10), sharey=True)
fig.suptitle("Bootstrap values of the maximum likelihood reconstruction depending on data type and trimming strategie")

# seedplants
sns.boxplot(ax = axes[0], x="data type", y="value", hue = "trimming", data=df_seedplants_melted, palette="Set3", order=order_seedplants) #inner="quart", cut=0
axes[0].set_title("a) Seed plants")

# gymno
sns.boxplot(ax = axes[1], x="data type", y="value", hue = "trimming", data=df_gymno_melted, palette="Set3", order=order_gymno) #inner="quart", cut=0
axes[1].set_title("b) Gymnosperms")

# angio
sns.boxplot(ax = axes[2], x="data type", y="value", hue = "trimming", data=df_angio_melted, palette="Set3", order=order_angio) #inner="quart", cut=0
axes[2].set_title("c) Angiosperms")

for ax in axes:
    ax.tick_params(axis='x', rotation=45)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.set(xlabel="Data type")
    ax.set(ylabel="Bootstrap values")
    ax.yaxis.set_tick_params(labelbottom=True)

plt.show()


#sns.stripplot(x="data type", y="value", hue="trimming", data=df_melted, palette= 'Set2', alpha=0.5, jitter=True)
#sns.violinplot(x="data type", y="value", hue = "trimming", data=df_melted, palette="Set3", order=order, inner="quart", cut=0)
#sns.stripplot(x="data type", y="value", hue="trimming", data=df_melted, palette= 'Set2', alpha=0.5, jitter=True)

# %% [markdown]
# ### baliphy

# %%
baliphy_trees_seedplants = ["results_baliphy_seedplants_cycas_codons/Results/greedy.PP.tree.support", "seed_plants_domain_codon/Results/greedy.PP.tree.support", "results_baliphy_seedplants_cycas_aa/Results/greedy.PP.tree.support", "seed_plants_domain_aa/Results/greedy.PP.tree.support" ]

baliphy_trees_gymno = ["gymno_cycas_codon/Results/greedy.PP.tree.support", "gymno_domain_codon/Results/greedy.PP.tree.support", "gymno_cycas_aa/Results/greedy.PP.tree.support", "gymno_domain_aa/Results/greedy.PP.tree.support",]

baliphy_trees_angio = ["results_baliphy_angio_codon/Results/greedy.PP.tree.support", "angio_domain_codon/Results/greedy.PP.tree.support", "results_baliphy_angio_aa/Results/greedy.PP.tree.support", "angio_domain_aa/Results/greedy.PP.tree.support",]

path = "/mnt/pbil/Infer_Anth/align/baliphy/Cycas/"
names = ["codon_complete", "codon_domain", "aa_complete", "aa_domain"]

dicts_baliphy_seedplants = {i:[] for i in names}
for analysis,name in zip(baliphy_trees_seedplants, names):
    for line in open(path+analysis):    
        a = line.strip()
        if a.replace('.','',1).isdigit():
            dicts_baliphy_seedplants[name].append(float(a)) 



dicts_baliphy_gymno = {i:[] for i in names}
for analysis,name in zip(baliphy_trees_gymno, names):
    for line in open(path+analysis):    
        a = line.strip()
        if a.replace('.','',1).isdigit():
            dicts_baliphy_gymno[name].append(float(a)) 


dicts_baliphy_angio = {i:[] for i in names}
for analysis,name in zip(baliphy_trees_angio, names):
    for line in open(path+analysis):    
        a = line.strip()
        if a.replace('.','',1).isdigit():
            dicts_baliphy_angio[name].append(float(a))

# %%
for i in dicts_baliphy_seedplants:
    print(len(dicts_baliphy_seedplants[i]))

for i in dicts_baliphy_gymno:
    print(len(dicts_baliphy_gymno[i]))

for i in dicts_baliphy_angio:
    print(len(dicts_baliphy_angio[i]))
# Out:
# 68
# 135
# 68
# 135
# 72
# 72
# 72
# 72
# 66
# 66
# 66
# 66

# %%
gymno_df = pd.DataFrame(dicts_baliphy_gymno).T
gymno_df["data_type"] = gymno_df.index

angio_df = pd.DataFrame(dicts_baliphy_angio).T
angio_df["data_type"] = angio_df.index

# %%
angio_melted = pd.melt(angio_df, id_vars=["data_type"], 
                    value_vars=list(range(66)),
                    var_name="category", value_name="value")


gymno_melted = pd.melt(gymno_df, id_vars=["data_type"], 
                    value_vars=list(range(72)),
                    var_name="category", value_name="value")



data_seedplants = {'Valeurs': np.concatenate([dicts_baliphy_seedplants[i] for i in dicts_baliphy_seedplants ]),
        'Listes': (["codon_complete"] * 68 + 
                   ['codon_domain'] * 135 + 
                   ['aa_complete'] * 68 + 
                   ['aa_domain'] * 135)}

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6), sharey=True)
fig.suptitle("Posterior probabilities of the Baliphy reconstruction considering greedy tree consensus")

sns.boxplot(ax = axes[0], x='Listes', y='Valeurs', data=data_seedplants, palette="Set3")
axes[0].set_title("a) Seed plants")
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# gymno
sns.boxplot(ax = axes[1], x="data_type", y="value", data=gymno_melted, palette="Set3") #inner="quart", cut=0
axes[1].set_title("b) Gymnosperms")
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1].set(xlabel=None)
axes[1].set(ylabel=None)
axes[1].yaxis.set_tick_params(labelbottom=True)


# angio
sns.boxplot(ax = axes[2], x="data_type", y="value", data=angio_melted, palette="Set3") #inner="quart", cut=0
axes[2].set_title("c) Angiosperms")
axes[2].tick_params(axis='x', rotation=45)
axes[2].grid(axis='y', linestyle='--', alpha=0.7)
axes[2].set(xlabel=None)
axes[2].set(ylabel=None)
axes[2].yaxis.set_tick_params(labelbottom=True)


plt.show()
#sns.violinplot(x="data type", y="value", hue = "trimming", data=df_melted, palette="Set3", order=order, inner="quart", cut=0)
#sns.stripplot(x="data type", y="value", hue="trimming", data=df_melted, palette= 'Set2', alpha=0.5, jitter=True)

# %% [markdown]
# # Alignements statistics

# %%
Seedplant_df = pd.read_csv("/mnt/pbil/Infer_Anth/align/seedplants/cycas/stats_align.csv", sep="\t")

# %%
Seedplant_df.head()
# Out:
#      data_type     trimming    align  length  gaps
# 0  complete_aa  no_trimming  clustal     319  41.4
# 1  complete_aa  no_trimming    macse     653  71.4
# 2  complete_aa  no_trimming    mafft     477  60.8
# 3  complete_aa  no_trimming   muscle     657  71.6
# 4  complete_aa   hmmcleaner  clustal     273  54.9

# %%
order_seedplants = ["domain_codon", "complete_aa", "domain_aa",  "complete_nt", "domain_nt"]


fig, axes = plt.subplots(1, 2, figsize=(20, 6))
fig.suptitle("Statistics on Seed plant dataset alignments")

sns.barplot(ax = axes[0], 
            x="data_type", y="length", hue = "align", data=Seedplant_df, order = order_seedplants, palette="Set3")

axes[0].set_title("a) Alignment length")
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)
axes[0].set(xlabel="Data type")
axes[0].set(ylabel="Alignment length")


sns.barplot(ax = axes[1], 
            x="data_type", y="gaps", hue = "align", data=Seedplant_df, order = order_seedplants, palette="Set3")
axes[1].set_title("b) Gap percentage")
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1].set(xlabel="Data type")
axes[1].set(ylabel="gap percentage")

plt.grid()
plt.show()

# %%
complete_seed_aa = Seedplant_df[Seedplant_df.data_type == "complete_aa" ]
domain_seed_aa = Seedplant_df[Seedplant_df.data_type == "domain_aa" ]

# %%
order_seedplants = ["clustal", "mafft", "macse",  "muscle", "baliphy"]


fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle("Statistics on the seed plant dataset alignments with amino-acid encoding")

sns.barplot(ax = axes[0,0], 
            x="trimming", y="length", hue = "align", data=complete_seed_aa, palette="Set3")

axes[0,0].set_title("a) Alignment length complete aa")
axes[0,0].tick_params(axis='x')
axes[0,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,0].set(xlabel="")
axes[0,0].set(ylabel="Alignment length")
axes[0,0].set_ylim([0,1020])



sns.barplot(ax = axes[0,1], 
            x="trimming", y="length", hue = "align", data=domain_seed_aa, palette="Set3")

axes[0,1].set_title("b) Alignment length domain aa")
axes[0,1].tick_params(axis='x')
axes[0,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,1].set(xlabel="")
axes[0,1].set(ylabel="Alignment length")
axes[0,1].set_ylim([0,205])



sns.barplot(ax = axes[1,0], 
            x="trimming", y="gaps", hue = "align", data=complete_seed_aa, palette="Set3")
axes[1,0].set_title("c) Gap percentage complete aa")
axes[1,0].tick_params(axis='x')
axes[1,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,0].set(xlabel="")
axes[1,0].set(ylabel="gap percentage")
axes[1,0].set_ylim([0,85])


sns.barplot(ax = axes[1,1], 
            x="trimming", y="gaps", hue = "align", data=domain_seed_aa, palette="Set3")
axes[1,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,1].set_title("d) Gap percentage domain aa")
axes[1,1].tick_params(axis='x')
axes[1,1].set(xlabel="")
axes[1,1].set(ylabel="gap percentage")
axes[1,1].set_ylim([0,45])

plt.savefig("/mnt/pbil/Infer_Anth/align/seedplants/cycas/alignment_statistics_baliphy.svg", format="svg")
plt.savefig("/mnt/pbil/Infer_Anth/align/seedplants/cycas/alignment_statistics_baliphy.pdf", format="pdf")

# %% [markdown]
# ## Gymnosperms

# %%
gymno_df = pd.read_csv("/mnt/pbil/Infer_Anth/align/gymno/align_stats_baliphy.csv", sep="\t")

gymno_aa = gymno_df[gymno_df.data_type == "complete_aa" ]
gymno_domain_aa = gymno_df[gymno_df.data_type == "domain_aa" ]

# %%
#order_seedplants = ["clustal", "mafft", "macse",  "muscle", "baliphy"]

fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle("Statistics on the Gymnosperm dataset alignments with amino-acid encoding")

sns.barplot(ax = axes[0,0], 
            x="trimming", y="length", hue = "align", data=gymno_aa, palette="Set3")

axes[0,0].set_title("a) Alignment length complete aa")
axes[0,0].tick_params(axis='x')
axes[0,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,0].set(xlabel="")
axes[0,0].set(ylabel="Alignment length")
axes[0,0].set_ylim([0,820])



sns.barplot(ax = axes[0,1], 
            x="trimming", y="length", hue = "align", data=gymno_domain_aa, palette="Set3")

axes[0,1].set_title("b) Alignment length domain aa")
axes[0,1].tick_params(axis='x')
axes[0,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,1].set(xlabel="")
axes[0,1].set(ylabel="Alignment length")
axes[0,1].set_ylim([0,205])



sns.barplot(ax = axes[1,0], 
            x="trimming", y="gaps", hue = "align", data=gymno_aa, palette="Set3")
axes[1,0].set_title("c) Gap percentage complete aa")
axes[1,0].tick_params(axis='x')
axes[1,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,0].set(xlabel="")
axes[1,0].set(ylabel="gap percentage")
axes[1,0].set_ylim([0,85])


sns.barplot(ax = axes[1,1], 
            x="trimming", y="gaps", hue = "align", data=gymno_domain_aa, palette="Set3")
axes[1,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,1].set_title("d) Gap percentage domain aa")
axes[1,1].tick_params(axis='x')
axes[1,1].set(xlabel="")
axes[1,1].set(ylabel="gap percentage")
axes[1,1].set_ylim([0,35])

plt.savefig("/mnt/pbil/Infer_Anth/align/gymno/alignment_statistics_baliphy.svg", format="svg")
plt.savefig("/mnt/pbil/Infer_Anth/align/gymno/alignment_statistics_baliphy.pdf", format="pdf")

# %% [markdown]
# ## Angiosperms

# %%
angio_df = pd.read_csv("/mnt/pbil/Infer_Anth/align/angio/stats_align_angio_baliphy.csv", sep="\t")

angio_aa = angio_df[angio_df.data_type == "complete_aa" ]
angio_domain_aa = angio_df[angio_df.data_type == "domain_aa"]

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle("Statistics on the Angiosperm dataset alignments with amino-acid encoding")

sns.barplot(ax = axes[0,0], 
            x="trimming", y="length", hue = "align", data=angio_aa, palette="Set3")

axes[0,0].set_title("a) Alignment length complete aa")
axes[0,0].tick_params(axis='x')
axes[0,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,0].set(xlabel="")
axes[0,0].set(ylabel="Alignment length")
axes[0,0].set_ylim([0,1820])



sns.barplot(ax = axes[0,1], 
            x="trimming", y="length", hue = "align", data=angio_domain_aa, palette="Set3")

axes[0,1].set_title("b) Alignment length domain aa")
axes[0,1].tick_params(axis='x')
axes[0,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,1].set(xlabel="")
axes[0,1].set(ylabel="Alignment length")
axes[0,1].set_ylim([0,205])



sns.barplot(ax = axes[1,0], 
            x="trimming", y="gaps", hue = "align", data=angio_aa, palette="Set3")
axes[1,0].set_title("c) Gap percentage complete aa")
axes[1,0].tick_params(axis='x')
axes[1,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,0].set(xlabel="")
axes[1,0].set(ylabel="gap percentage")
axes[1,0].set_ylim([0,95])


sns.barplot(ax = axes[1,1], 
            x="trimming", y="gaps", hue = "align", data=angio_domain_aa, palette="Set3")
axes[1,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,1].set_title("d) Gap percentage domain aa")
axes[1,1].tick_params(axis='x')
axes[1,1].set(xlabel="")
axes[1,1].set(ylabel="gap percentage")
axes[1,1].set_ylim([0,35])

plt.savefig("/mnt/pbil/Infer_Anth/align/angio/alignment_statistics_aa_baliphy.svg", format="svg")
plt.savefig("/mnt/pbil/Infer_Anth/align/angio/alignment_statistics_aa_baliphy.pdf", format="pdf")

# %%
angio_codon = angio_df[angio_df.data_type == "complete_codon" ]
angio_domain_codon = angio_df[angio_df.data_type == "domain_codon"]


fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle("Statistics on the Angiosperm dataset alignments with codon encoding")

sns.barplot(ax = axes[0,0], 
            x="trimming", y="length", hue = "align", data=angio_codon, palette="Set3")

axes[0,0].set_title("a) Alignment length complete codon")
axes[0,0].tick_params(axis='x')
axes[0,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,0].set(xlabel="")
axes[0,0].set(ylabel="Alignment length")
axes[0,0].set_ylim([0,4820])



sns.barplot(ax = axes[0,1], 
            x="trimming", y="length", hue = "align", data=angio_domain_codon, palette="Set3")

axes[0,1].set_title("b) Alignment length domain codon")
axes[0,1].tick_params(axis='x')
axes[0,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,1].set(xlabel="")
axes[0,1].set(ylabel="Alignment length")
axes[0,1].set_ylim([0,615])



sns.barplot(ax = axes[1,0], 
            x="trimming", y="gaps", hue = "align", data=angio_codon, palette="Set3")
axes[1,0].set_title("c) Gap percentage complete codon")
axes[1,0].tick_params(axis='x')
axes[1,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,0].set(xlabel="")
axes[1,0].set(ylabel="gap percentage")
axes[1,0].set_ylim([0,95])


sns.barplot(ax = axes[1,1], 
            x="trimming", y="gaps", hue = "align", data=angio_domain_codon, palette="Set3")
axes[1,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,1].set_title("d) Gap percentage domain codon")
axes[1,1].tick_params(axis='x')
axes[1,1].set(xlabel="")
axes[1,1].set(ylabel="gap percentage")
axes[1,1].set_ylim([0,35])

plt.savefig("/mnt/pbil/Infer_Anth/align/angio/alignment_statistics_codon_baliphy.svg", format="svg")
plt.savefig("/mnt/pbil/Infer_Anth/align/angio/alignment_statistics_codon_baliphy.pdf", format="pdf")

# %% [markdown]
# ## Mix alignment length

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 15))
#fig.suptitle("Alignment length depending on aligning tools using amino-acid encoding on complete and domain sequences")

sns.barplot(ax = axes[0,0], x="trimming", y="length", hue = "align", data=complete_seed_aa, palette="Set3")
axes[0,0].set_title("a) Seed plants complete")
axes[0,0].tick_params(axis='x', rotation=45)
axes[0,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,0].set(xlabel=None)
axes[0,0].set_ylim([0,1820])
# gymno
sns.barplot(ax = axes[0,1],  x="trimming", y="length", hue = "align", data=gymno_aa, palette="Set3") #inner="quart", cut=0
axes[0,1].set_title("b) Gymnosperms complete")
axes[0,1].tick_params(axis='x', rotation=45)
axes[0,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,1].set(xlabel=None)
axes[0,1].set(ylabel=None)
axes[0,1].yaxis.set_tick_params(labelbottom=True)
axes[0,1].set_ylim([0,1820])

# angio
sns.barplot(ax = axes[0,2],  x="trimming", y="length", hue = "align", data=angio_aa, palette="Set3") #inner="quart", cut=0
axes[0,2].set_title("c) Angiosperms complete")
axes[0,2].tick_params(axis='x', rotation=45)
axes[0,2].grid(axis='y', linestyle='--', alpha=0.7)
axes[0,2].set(xlabel=None)
axes[0,2].set(ylabel=None)
axes[0,2].yaxis.set_tick_params(labelbottom=True)
axes[0,2].set_ylim([0,1820])

sns.barplot(ax = axes[1,0], x="trimming", y="length", hue = "align", data=domain_seed_aa, palette="Set3")
axes[1,0].set_title("d) Seed plants domain")
axes[1,0].tick_params(axis='x', rotation=45)
axes[1,0].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,0].set(xlabel=None)
axes[1,0].set_ylim([0,220])
# gymno
sns.barplot(ax = axes[1,1],  x="trimming", y="length", hue = "align", data=gymno_domain_aa, palette="Set3") #inner="quart", cut=0
axes[1,1].set_title("e) Gymnosperms domain")
axes[1,1].tick_params(axis='x', rotation=45)
axes[1,1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,1].set(xlabel=None)
axes[1,1].set(ylabel=None)
axes[1,1].yaxis.set_tick_params(labelbottom=True)
axes[1,1].set_ylim([0,220])

# angio
sns.barplot(ax = axes[1,2],  x="trimming", y="length", hue = "align", data=angio_domain_aa, palette="Set3") #inner="quart", cut=0
axes[1,2].set_title("f) Angiosperms domain")
axes[1,2].tick_params(axis='x', rotation=45)
axes[1,2].grid(axis='y', linestyle='--', alpha=0.7)
axes[1,2].set(xlabel=None)
axes[1,2].set(ylabel=None)
axes[1,2].yaxis.set_tick_params(labelbottom=True)
axes[1,2].set_ylim([0,220])




plt.savefig("/mnt/pbil/Infer_Anth/align/alignment_statistics_aa_complete_domain.svg", format="svg", bbox_inches='tight')
plt.savefig("/mnt/pbil/Infer_Anth/align/alignment_statistics_aa_complete_domain.pdf", format="pdf", bbox_inches='tight')
